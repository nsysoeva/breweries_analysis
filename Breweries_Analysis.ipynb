# %% [markdown]
# # Breweries Analysis

# %% [markdown]
# ### Exploratory Data Analysis

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

# %%
brews = pd.read_csv("C:\\Users\\ninas\\OneDrive\\Desktop\\Learning\\Data Science Bootcamp\\Project\\Beer\\brewery_data_complete_extended.csv")

# %%
brews["Quality_Score"].round(1).value_counts()
# Out:
# Quality_Score
# 6.4     251106
# 7.5     251066
# 7.9     251047
# 8.5     250705
# 6.9     250637
# 7.7     250518
# 9.4     250516
# 6.6     250455
# 9.3     250379
# 6.1     250328
# 8.2     250321
# 9.2     250262
# 9.8     250229
# 8.7     250210
# 9.1     250193
# 6.3     250139
# 8.4     250116
# 7.2     250075
# 9.5     250050
# 8.3     250025
# 9.6     250008
# 7.0     249936
# 6.2     249913
# 8.6     249900
# 8.0     249819
# 8.8     249770
# 7.3     249701
# 6.5     249696
# 9.0     249654
# 8.1     249595
# 8.9     249564
# 9.9     249505
# 7.6     249496
# 7.8     249447
# 7.1     249321
# 6.7     249318
# 6.8     249289
# 9.7     248988
# 7.4     248819
# 6.0     125031
# 10.0    124853
# Name: count, dtype: int64

# %%
# Let's view sample first rows and sample from the dataset to get an idea of what we have in it
brews.head()
# Out:
#    Batch_ID            Brew_Date  Beer_Style   SKU      Location  \
# 0   7870796  2020-01-01 00:00:19  Wheat Beer  Kegs    Whitefield
# 1   9810411  2020-01-01 00:00:31        Sour  Kegs    Whitefield
# 2   2623342  2020-01-01 00:00:40  Wheat Beer  Kegs   Malleswaram
# 3   8114651  2020-01-01 00:01:37         Ale  Kegs   Rajajinagar
# 4   4579587  2020-01-01 00:01:43       Stout  Cans  Marathahalli
#
#    Fermentation_Time  Temperature  pH_Level   Gravity  Alcohol_Content  \
# 0                 16    24.204251  5.289845  1.039504         5.370842
# 1                 13    18.086763  5.275643  1.059819         5.096053
# 2                 12    15.539333  4.778016  1.037476         4.824737
# 3                 17    16.418489  5.345261  1.052431         5.509243
# 4                 18    19.144908  4.861854  1.054296         5.133625
#
#    Bitterness  Color Ingredient_Ratio  Volume_Produced   Total_Sales  \
# 0          20      5      1:0.32:0.16             4666   2664.759345
# ...

# %%
plt.figure()
plt.scatter(brews["Alcohol_Content"], brews["Bitterness"])
plt.xlabel('Alcohol_Content')
plt.ylabel('Bitterness')
plt.title("Scatter Plot")
plt.show()

# %%
plt.figure()
plt.scatter(brews["Total_Sales"], brews["Quality_Score"])
plt.xlabel('Total_Sales')
plt.ylabel('Quality_Score')
plt.title("Scatter Plot")
plt.show()

# %%
brews.groupby(["Beer_Style"])[["Fermentation_Time", "Temperature", "pH_Level", "Gravity", "Alcohol_Content", "Bitterness", "Color", "Volume_Produced", "Total_Sales", "Quality_Score", "Brewhouse_Efficiency", "Loss_During_Brewing", "Loss_During_Fermentation", "Loss_During_Bottling_Kegging"]].mean()
# Out:
#             Fermentation_Time  Temperature  pH_Level   Gravity  \
# Beer_Style
# Ale                 14.501019    19.999627  4.999969  1.055006
# IPA                 14.499067    19.996046  4.999830  1.054991
# Lager               14.501280    20.001902  5.000051  1.054986
# Pilsner             14.501048    19.997734  5.000042  1.055004
# Porter              14.497252    19.999347  4.999764  1.055005
# Sour                14.500461    20.003314  4.999869  1.055031
# Stout               14.503157    19.998394  4.999911  1.055006
# Wheat Beer          14.503903    20.002825  5.000089  1.054996
#
#             Alcohol_Content  Bitterness      Color  Volume_Produced  \
# Beer_Style
# Ale                5.249216   39.498093  11.999430      2748.590063
# IPA                5.250116   39.494952  11.999718      2750.845711
# Lager              5.250009   39.490634  12.000880      2751.239931
# Pilsner            5.249688   39.498989  11.994849      2749.706035
# ...

# %%
brews.sample(10)
# Out:
#          Batch_ID            Brew_Date  Beer_Style      SKU         Location  \
# 1065694   4781506  2020-06-04 16:27:57        Sour    Pints        Jayanagar
# 9336043   1005032  2023-09-26 03:16:03         IPA     Cans       HSR Layout
# 6984474   5010371  2022-10-17 14:43:34  Wheat Beer    Pints      Koramangala
# 2108260   6871765  2020-11-04 04:07:24      Porter     Cans        Yelahanka
# 5172228   8647613  2022-01-25 17:18:30         Ale  Bottles     Marathahalli
# 8631188   8016078  2023-06-15 01:46:57         IPA  Bottles        Jayanagar
# 2961424   1409281  2021-03-08 14:42:03         IPA  Bottles       HSR Layout
# 5533805   3155387  2022-03-19 10:59:25  Wheat Beer  Bottles  Electronic City
# 5300779   1620872  2022-02-13 10:53:51         IPA    Pints      Malleswaram
# 1807361   7331525  2020-09-21 04:01:12  Wheat Beer     Kegs     Marathahalli
#
#          Fermentation_Time  Temperature  pH_Level   Gravity  Alcohol_Content  \
# ...

# %%
brews.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000000 entries, 0 to 9999999
# Data columns (total 20 columns):
#  #   Column                        Dtype
# ---  ------                        -----
#  0   Batch_ID                      int64
#  1   Brew_Date                     object
#  2   Beer_Style                    object
#  3   SKU                           object
#  4   Location                      object
#  5   Fermentation_Time             int64
#  6   Temperature                   float64
#  7   pH_Level                      float64
#  8   Gravity                       float64
#  9   Alcohol_Content               float64
#  10  Bitterness                    int64
#  11  Color                         int64
#  12  Ingredient_Ratio              object
#  13  Volume_Produced               int64
#  14  Total_Sales                   float64
#  15  Quality_Score                 float64
#  16  Brewhouse_Efficiency          float64
# ...

# %%
# We have a set of categoriecal fields (objects) that would need to be taken care of in order to proceed with the statistical modeling

# %%
brews.groupby(["Location"])["Location"].count()
# These are all different locations that we have in the database (various areas in Bangalore)
# Out:
# Location
# Electronic City     999307
# HSR Layout         1000789
# Indiranagar         999887
# Jayanagar          1000760
# Koramangala        1000220
# Malleswaram         999629
# Marathahalli       1000164
# Rajajinagar        1000147
# Whitefield          999279
# Yelahanka           999818
# Name: Location, dtype: int64

# %%
brews.sort_values(by="Brew_Date")
# Data is from Jan 2020 to Dec 2023
# Out:
#          Batch_ID            Brew_Date  Beer_Style      SKU         Location  \
# 0         7870796  2020-01-01 00:00:19  Wheat Beer     Kegs       Whitefield
# 1         9810411  2020-01-01 00:00:31        Sour     Kegs       Whitefield
# 2         2623342  2020-01-01 00:00:40  Wheat Beer     Kegs      Malleswaram
# 3         8114651  2020-01-01 00:01:37         Ale     Kegs      Rajajinagar
# 4         4579587  2020-01-01 00:01:43       Stout     Cans     Marathahalli
# ...           ...                  ...         ...      ...              ...
# 9999995   4575645  2023-12-31 23:58:59       Stout  Bottles        Yelahanka
# 9999996   2074362  2023-12-31 23:59:18  Wheat Beer  Bottles  Electronic City
# 9999997    177617  2023-12-31 23:59:41         IPA  Bottles      Malleswaram
# 9999998   7306891  2023-12-31 23:59:45         Ale     Kegs  Electronic City
# 9999999   5072143  2023-12-31 23:59:54  Wheat Beer    Pints  Electronic City
#
# ...

# %%
brews.shape
# Out:
# (10000000, 20)

# %%
# Let's create a smaller data set, with 50,000 rows instead of 10 milllion
brews_df = brews.sample(frac=0.005, random_state=10)

# %%
brews_df.to_csv(r'C:\\Users\\ninas\\OneDrive\\Desktop\\Learning\\Data Science Bootcamp\\Project\\Beer\\brews_df.csv', index=False)

# %%
brews_df.head()
# Out:
#          Batch_ID            Brew_Date Beer_Style      SKU         Location  \
# 2962955   8247848  2021-03-08 19:57:17    Pilsner  Bottles      Indiranagar
# 7621982    895526  2023-01-18 14:42:54    Pilsner  Bottles      Malleswaram
# 4254350     11072  2021-09-13 10:29:10     Porter    Pints       HSR Layout
# 7873153    314777  2023-02-24 06:30:28      Stout     Cans      Indiranagar
# 7869034   4353616  2023-02-23 15:50:05       Sour  Bottles  Electronic City
#
#          Fermentation_Time  Temperature  pH_Level   Gravity  Alcohol_Content  \
# 2962955                 19    17.830804  5.267129  1.035899         5.123284
# 7621982                 19    21.316022  4.870337  1.072140         4.653873
# 4254350                 13    16.605831  5.143604  1.056021         5.690139
# 7873153                 14    17.062998  5.211564  1.061697         4.888406
# 7869034                 12    21.546932  5.322301  1.041031         5.813500
#
# ...

# %%
brews_df.shape
# Now there are 50,000 rows and 20 columns in our dataset
# Out:
# (50000, 20)

# %%
# Total_Sales represent the total sales generated from the batch, expressed in a currency unit (USD, 2023 dollars)
# Volume_Produced represents the volume of beer produced in the batch, measured in liters.
# Newly calculated column "Revenue_Per_Liter" based on total sales and volume produced

brews_df["Revenue_Per_Liter"] = brews_df["Total_Sales"] / brews_df["Volume_Produced"]

# %%
brews_df.head()
# Out:
#          Batch_ID            Brew_Date Beer_Style      SKU         Location  \
# 2962955   8247848  2021-03-08 19:57:17    Pilsner  Bottles      Indiranagar
# 7621982    895526  2023-01-18 14:42:54    Pilsner  Bottles      Malleswaram
# 4254350     11072  2021-09-13 10:29:10     Porter    Pints       HSR Layout
# 7873153    314777  2023-02-24 06:30:28      Stout     Cans      Indiranagar
# 7869034   4353616  2023-02-23 15:50:05       Sour  Bottles  Electronic City
#
#          Fermentation_Time  Temperature  pH_Level   Gravity  Alcohol_Content  \
# 2962955                 19    17.830804  5.267129  1.035899         5.123284
# 7621982                 19    21.316022  4.870337  1.072140         4.653873
# 4254350                 13    16.605831  5.143604  1.056021         5.690139
# 7873153                 14    17.062998  5.211564  1.061697         4.888406
# 7869034                 12    21.546932  5.322301  1.041031         5.813500
#
# ...

# %%
# Checking for duplicate rows. None identified
brews_df.duplicated().sum()
# Out:
# 0

# %%
# Checking for duplicate columns. None identified
brews_df.T.duplicated().sum()
# Out:
# 0

# %%
# There are no missing values in each column
brews_df.isna().sum(axis=0)
# Out:
# Batch_ID                        0
# Brew_Date                       0
# Beer_Style                      0
# SKU                             0
# Location                        0
# Fermentation_Time               0
# Temperature                     0
# pH_Level                        0
# Gravity                         0
# Alcohol_Content                 0
# Bitterness                      0
# Color                           0
# Ingredient_Ratio                0
# Volume_Produced                 0
# Total_Sales                     0
# Quality_Score                   0
# Brewhouse_Efficiency            0
# Loss_During_Brewing             0
# Loss_During_Fermentation        0
# Loss_During_Bottling_Kegging    0
# Revenue_Per_Liter               0
# dtype: int64

# %%
brews_df.describe()
# Out:
#            Batch_ID  Fermentation_Time   Temperature      pH_Level  \
# count  5.000000e+04       50000.000000  50000.000000  50000.000000
# mean   4.991085e+06          14.524320     20.000750      4.999168
# std    2.892245e+06           2.871977      2.882409      0.288252
# min    2.750000e+02          10.000000     15.000265      4.500040
# 25%    2.472529e+06          12.000000     17.520539      4.749803
# 50%    4.996984e+06          15.000000     19.981049      4.999042
# 75%    7.491746e+06          17.000000     22.489827      5.248612
# max    9.999883e+06          19.000000     24.999369      5.499983
#
#             Gravity  Alcohol_Content    Bitterness         Color  \
# count  50000.000000     50000.000000  50000.000000  50000.000000
# mean       1.054959         5.250565     39.380740     11.986160
# std        0.014422         0.431942     11.549023      4.304832
# min        1.030001         4.500025     20.000000      5.000000
# ...

# %%
# It looks like we would need to perform feature scaling as part of our feature engineering process. Specifically, it appears that Volume Produced,
# Total Sales and Brewhouse Efficiency (to a lesser extent) should be scaled, provided that we use those variables in our modeling. 
# We would also need to change categorical variables (Beer Style, SKU, and Location) to dummy variables

# %%
cont_var = list(brews_df.select_dtypes(exclude='object'))
cont_var
# Out:
# ['Batch_ID',
#  'Fermentation_Time',
#  'Temperature',
#  'pH_Level',
#  'Gravity',
#  'Alcohol_Content',
#  'Bitterness',
#  'Color',
#  'Volume_Produced',
#  'Total_Sales',
#  'Quality_Score',
#  'Brewhouse_Efficiency',
#  'Loss_During_Brewing',
#  'Loss_During_Fermentation',
#  'Loss_During_Bottling_Kegging',
#  'Revenue_Per_Liter']

# %%
plt.subplots(4,4,figsize=(15,8))
plot_num=1
for col in cont_var:
    var = brews_df[col]
    var_mean = var.mean()
    var_median = var.median()
    
    plt.subplot(4,4,plot_num)
    sns.histplot(var)
    plt.axvline(var_mean, c="r", label="Mean")
    plt.axvline(var_median, c="g", label="Median")
    plt.legend()
    plot_num +=1
plt.tight_layout()
plt.show()

# %%
# From the above charts, we can see that most of the data is uniformly ditributed. This is likely due to the fact that our dataset is synthetic, it was
# presumably meant to capture all different scenarios / beer characteristics uniformly.

# %%
# Let's next deal with categorical variables (objects) by converting them into numerical variables
# First, let's change variable type of Brew_Date 
brews_df['Brew_Date'] = pd.to_datetime(brews_df['Brew_Date'])

# %%
brews_df["Beer_Style"].unique()
# Out:
# array(['Pilsner', 'Porter', 'Stout', 'Sour', 'IPA', 'Ale', 'Lager',
#        'Wheat Beer'], dtype=object)

# %%
brews_df["SKU"].unique()
# Out:
# array(['Bottles', 'Pints', 'Cans', 'Kegs'], dtype=object)

# %%
brews_df["Location"].unique()
# Out:
# array(['Indiranagar', 'Malleswaram', 'HSR Layout', 'Electronic City',
#        'Koramangala', 'Jayanagar', 'Rajajinagar', 'Whitefield',
#        'Marathahalli', 'Yelahanka'], dtype=object)

# %%
brews_df["Ingredient_Ratio"].unique()
# Out:
# array(['1:0.26:0.26', '1:0.50:0.28', '1:0.37:0.17', '1:0.22:0.11',
#        '1:0.32:0.28', '1:0.36:0.13', '1:0.42:0.24', '1:0.26:0.28',
#        '1:0.23:0.10', '1:0.30:0.30', '1:0.40:0.11', '1:0.43:0.22',
#        '1:0.46:0.26', '1:0.21:0.27', '1:0.33:0.21', '1:0.40:0.16',
#        '1:0.49:0.29', '1:0.43:0.12', '1:0.23:0.20', '1:0.40:0.25',
#        '1:0.33:0.27', '1:0.43:0.29', '1:0.45:0.29', '1:0.42:0.25',
#        '1:0.43:0.16', '1:0.36:0.29', '1:0.31:0.24', '1:0.40:0.13',
#        '1:0.45:0.21', '1:0.41:0.18', '1:0.35:0.20', '1:0.20:0.23',
#        '1:0.21:0.29', '1:0.38:0.12', '1:0.49:0.22', '1:0.48:0.24',
#        '1:0.31:0.11', '1:0.46:0.30', '1:0.27:0.29', '1:0.21:0.25',
#        '1:0.44:0.12', '1:0.45:0.16', '1:0.49:0.18', '1:0.26:0.21',
#        '1:0.29:0.25', '1:0.30:0.10', '1:0.38:0.22', '1:0.34:0.11',
#        '1:0.47:0.18', '1:0.43:0.25', '1:0.47:0.14', '1:0.49:0.24',
#        '1:0.45:0.27', '1:0.21:0.22', '1:0.42:0.13', '1:0.49:0.19',
# ...

# %%
# After speaking with the creator of the database, who is experienced in the subject matter, I've learned that the ingredient ratio represents
# water : grains : hops. The ratio would vary with the type of beer (Beer_Style column)

# %%
pd.pandas.set_option('display.max_columns', None)

# %%
brews_df[["Water","Grains","Hops"]] = brews_df["Ingredient_Ratio"].str.split(":", expand=True)
brews_df.head()
# Out:
#          Batch_ID           Brew_Date Beer_Style      SKU         Location  \
# 2962955   8247848 2021-03-08 19:57:17    Pilsner  Bottles      Indiranagar
# 7621982    895526 2023-01-18 14:42:54    Pilsner  Bottles      Malleswaram
# 4254350     11072 2021-09-13 10:29:10     Porter    Pints       HSR Layout
# 7873153    314777 2023-02-24 06:30:28      Stout     Cans      Indiranagar
# 7869034   4353616 2023-02-23 15:50:05       Sour  Bottles  Electronic City
#
#          Fermentation_Time  Temperature  pH_Level   Gravity  Alcohol_Content  \
# 2962955                 19    17.830804  5.267129  1.035899         5.123284
# 7621982                 19    21.316022  4.870337  1.072140         4.653873
# 4254350                 13    16.605831  5.143604  1.056021         5.690139
# 7873153                 14    17.062998  5.211564  1.061697         4.888406
# 7869034                 12    21.546932  5.322301  1.041031         5.813500
#
# ...

# %%
# Let's now drop ingredient ratio column (because we have just split it into three columns) and water column (because it is always 1 as database
# creator has explained to me)
brews_df = brews_df.drop(["Ingredient_Ratio", "Water", "Volume_Produced", "Total_Sales"], axis=1)
brews_df.head()
# Out:
#          Batch_ID           Brew_Date Beer_Style      SKU         Location  \
# 2962955   8247848 2021-03-08 19:57:17    Pilsner  Bottles      Indiranagar
# 7621982    895526 2023-01-18 14:42:54    Pilsner  Bottles      Malleswaram
# 4254350     11072 2021-09-13 10:29:10     Porter    Pints       HSR Layout
# 7873153    314777 2023-02-24 06:30:28      Stout     Cans      Indiranagar
# 7869034   4353616 2023-02-23 15:50:05       Sour  Bottles  Electronic City
#
#          Fermentation_Time  Temperature  pH_Level   Gravity  Alcohol_Content  \
# 2962955                 19    17.830804  5.267129  1.035899         5.123284
# 7621982                 19    21.316022  4.870337  1.072140         4.653873
# 4254350                 13    16.605831  5.143604  1.056021         5.690139
# 7873153                 14    17.062998  5.211564  1.061697         4.888406
# 7869034                 12    21.546932  5.322301  1.041031         5.813500
#
# ...

# %%
brews_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 50000 entries, 2962955 to 7445576
# Data columns (total 20 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Batch_ID                      50000 non-null  int64
#  1   Brew_Date                     50000 non-null  datetime64[ns]
#  2   Beer_Style                    50000 non-null  object
#  3   SKU                           50000 non-null  object
#  4   Location                      50000 non-null  object
#  5   Fermentation_Time             50000 non-null  int64
#  6   Temperature                   50000 non-null  float64
#  7   pH_Level                      50000 non-null  float64
#  8   Gravity                       50000 non-null  float64
#  9   Alcohol_Content               50000 non-null  float64
#  10  Bitterness                    50000 non-null  int64
#  11  Color                         50000 non-null  int64
# ...

# %%
# Converting Grains and Hops columns to numerical variables
brews_df["Grains"] = brews_df["Grains"].astype("float")
brews_df["Hops"] = brews_df["Hops"].astype("float")

# %%
brews_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 50000 entries, 2962955 to 7445576
# Data columns (total 20 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Batch_ID                      50000 non-null  int64
#  1   Brew_Date                     50000 non-null  datetime64[ns]
#  2   Beer_Style                    50000 non-null  object
#  3   SKU                           50000 non-null  object
#  4   Location                      50000 non-null  object
#  5   Fermentation_Time             50000 non-null  int64
#  6   Temperature                   50000 non-null  float64
#  7   pH_Level                      50000 non-null  float64
#  8   Gravity                       50000 non-null  float64
#  9   Alcohol_Content               50000 non-null  float64
#  10  Bitterness                    50000 non-null  int64
#  11  Color                         50000 non-null  int64
# ...

# %%
# Getting dummy variables for categorical columns
brews_df = pd.get_dummies(brews_df, dtype=int, drop_first=True)

# %%
brews_df.head()
# Out:
#          Batch_ID           Brew_Date  Fermentation_Time  Temperature  \
# 2962955   8247848 2021-03-08 19:57:17                 19    17.830804
# 7621982    895526 2023-01-18 14:42:54                 19    21.316022
# 4254350     11072 2021-09-13 10:29:10                 13    16.605831
# 7873153    314777 2023-02-24 06:30:28                 14    17.062998
# 7869034   4353616 2023-02-23 15:50:05                 12    21.546932
#
#          pH_Level   Gravity  Alcohol_Content  Bitterness  Color  \
# 2962955  5.267129  1.035899         5.123284          27      6
# 7621982  4.870337  1.072140         4.653873          46     19
# 4254350  5.143604  1.056021         5.690139          47     17
# 7873153  5.211564  1.061697         4.888406          59     12
# 7869034  5.322301  1.041031         5.813500          21     17
#
#          Quality_Score  Brewhouse_Efficiency  Loss_During_Brewing  \
# 2962955       6.404044             85.865930             3.008925
# ...

# %%
brews_df.info()
# There are no more categorical variables
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 50000 entries, 2962955 to 7445576
# Data columns (total 36 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Batch_ID                      50000 non-null  int64
#  1   Brew_Date                     50000 non-null  datetime64[ns]
#  2   Fermentation_Time             50000 non-null  int64
#  3   Temperature                   50000 non-null  float64
#  4   pH_Level                      50000 non-null  float64
#  5   Gravity                       50000 non-null  float64
#  6   Alcohol_Content               50000 non-null  float64
#  7   Bitterness                    50000 non-null  int64
#  8   Color                         50000 non-null  int64
#  9   Quality_Score                 50000 non-null  float64
#  10  Brewhouse_Efficiency          50000 non-null  float64
#  11  Loss_During_Brewing           50000 non-null  float64
# ...

# %%
brews_df.shape
# Out:
# (50000, 36)

# %%
brews_df.corr()
# Out:
#                               Batch_ID  Brew_Date  Fermentation_Time  \
# Batch_ID                      1.000000  -0.001049           0.001957
# Brew_Date                    -0.001049   1.000000          -0.010806
# Fermentation_Time             0.001957  -0.010806           1.000000
# Temperature                   0.001691   0.003488           0.010558
# pH_Level                      0.000507   0.001391           0.000569
# Gravity                      -0.008868  -0.000149           0.008207
# Alcohol_Content               0.002508   0.000684           0.004636
# Bitterness                    0.002723   0.002580          -0.006173
# Color                        -0.005439   0.000285           0.001376
# Quality_Score                -0.004328  -0.000785           0.000466
# Brewhouse_Efficiency         -0.001671  -0.000693          -0.004393
# Loss_During_Brewing          -0.001694   0.006197          -0.003809
# Loss_During_Fermentation     -0.003152   0.002704           0.005210
# ...

# %% [markdown]
# ### Linear Regression

# %%
X = brews_df.drop("Revenue_Per_Liter", axis=1)
y = brews_df["Revenue_Per_Liter"]

# %%
X
# Out:
#          Batch_ID           Brew_Date  Fermentation_Time  Temperature  \
# 2962955   8247848 2021-03-08 19:57:17                 19    17.830804
# 7621982    895526 2023-01-18 14:42:54                 19    21.316022
# 4254350     11072 2021-09-13 10:29:10                 13    16.605831
# 7873153    314777 2023-02-24 06:30:28                 14    17.062998
# 7869034   4353616 2023-02-23 15:50:05                 12    21.546932
# ...           ...                 ...                ...          ...
# 6528231   4137069 2022-08-11 19:04:54                 14    18.169694
# 6714322    267066 2022-09-08 00:00:29                 13    19.278770
# 5823790   3242827 2022-04-30 21:27:59                 11    16.482225
# 7127      5632492 2020-01-02 00:55:42                 16    24.331978
# 7445576   7454220 2022-12-23 22:19:04                 12    16.706613
#
#          pH_Level   Gravity  Alcohol_Content  Bitterness  Color  \
# ...

# %%
corr_df = X.corr()
mask=np.triu(corr_df)
plt.figure(figsize=(20,20))
sns.heatmap(corr_df.round(2), annot=True, vmax=1, vmin=-1, center=0, cmap="coolwarm", mask=mask)
plt.show()

# %%
# Looking at the above, we can see that all correlations are 0.5 or below. We can continue with building our model

# %%
# Let's try to fit a linear regression model without dropping any variables

# %%
#from sklearn.model_selection import train_test_split

#X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=17)

# %%
#from sklearn.linear_model import LinearRegression 

#regression_model = LinearRegression()
#regression_model.fit(X_train, y_train)

#print(regression_model.score(X_train, y_train))
#print(regression_model.score(X_test, y_test))

# %%
#X_withconstant = sm.add_constant(X)

#myregression = sm.OLS(y, X_withconstant)
#myregression_results = myregression.fit()
#myregression_results.summary()

# %%
# Let's now test for milticollnearity using the Variance Inflation Factor (VIF) 
import statsmodels.api as sm
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
def calculate_vif(dataset):
    vif = pd.DataFrame()
    vif["features"] = dataset.columns
    vif["VIF_Value"] = [variance_inflation_factor(dataset.values,i)
                        for i in range(dataset.shape[1])]
    return(vif)

# %%
features = X.drop("Brew_Date", axis=1)
calculate_vif(features)
# Out:
#                         features   VIF_Value
# 0                       Batch_ID    3.976322
# 1              Fermentation_Time   26.516128
# 2                    Temperature   48.846718
# 3                       pH_Level  286.396599
# 4                        Gravity  737.790641
# 5                Alcohol_Content  145.220011
# 6                     Bitterness   12.607043
# 7                          Color    8.745536
# 8                  Quality_Score   48.625000
# 9           Brewhouse_Efficiency  187.328493
# 10           Loss_During_Brewing    7.690067
# 11      Loss_During_Fermentation    7.722461
# 12  Loss_During_Bottling_Kegging    7.795540
# 13                        Grains   17.292209
# 14                          Hops   12.836682
# 15                Beer_Style_IPA    2.003342
# 16              Beer_Style_Lager    2.000320
# 17            Beer_Style_Pilsner    1.994207
# 18             Beer_Style_Porter    1.985535
# 19               Beer_Style_Sour    2.011117
# ...

# %%
# We can see that some of the variables have VIF > 5, signalling multicollinearity. Let's drop them one by one, starting with Gravity.

# %%
features = X.drop(["Brew_Date", "Gravity"], axis=1)
calculate_vif(features)
# Out:
#                         features   VIF_Value
# 0                       Batch_ID    3.965297
# 1              Fermentation_Time   25.816731
# 2                    Temperature   46.483838
# 3                       pH_Level  193.995424
# 4                Alcohol_Content  122.868310
# 5                     Bitterness   12.451571
# 6                          Color    8.669543
# 7                  Quality_Score   46.426688
# 8           Brewhouse_Efficiency  149.452729
# 9            Loss_During_Brewing    7.646540
# 10      Loss_During_Fermentation    7.672821
# 11  Loss_During_Bottling_Kegging    7.738830
# 12                        Grains   16.998066
# 13                          Hops   12.678670
# 14                Beer_Style_IPA    1.995928
# 15              Beer_Style_Lager    1.993694
# 16            Beer_Style_Pilsner    1.986996
# 17             Beer_Style_Porter    1.979156
# 18               Beer_Style_Sour    2.002883
# 19              Beer_Style_Stout    1.998258
# ...

# %%
features = X.drop(["Brew_Date", "Gravity", "pH_Level"], axis=1)
calculate_vif(features)
# Out:
#                         features   VIF_Value
# 0                       Batch_ID    3.957037
# 1              Fermentation_Time   25.375968
# 2                    Temperature   45.046762
# 3                Alcohol_Content  108.937267
# 4                     Bitterness   12.354280
# 5                          Color    8.632873
# 6                  Quality_Score   44.885573
# 7           Brewhouse_Efficiency  125.545665
# 8            Loss_During_Brewing    7.616903
# 9       Loss_During_Fermentation    7.645564
# 10  Loss_During_Bottling_Kegging    7.707264
# 11                        Grains   16.844039
# 12                          Hops   12.579806
# 13                Beer_Style_IPA    1.990997
# 14              Beer_Style_Lager    1.989002
# 15            Beer_Style_Pilsner    1.981476
# 16             Beer_Style_Porter    1.974154
# 17               Beer_Style_Sour    1.997513
# 18              Beer_Style_Stout    1.993929
# 19         Beer_Style_Wheat Beer    1.976466
# ...

# %%
features = X.drop(["Brew_Date", "Gravity", "pH_Level", "Brewhouse_Efficiency"], axis=1)
calculate_vif(features)
# Out:
#                         features  VIF_Value
# 0                       Batch_ID   3.945675
# 1              Fermentation_Time  24.766379
# 2                    Temperature  42.849400
# 3                Alcohol_Content  88.413877
# 4                     Bitterness  12.209053
# 5                          Color   8.576367
# 6                  Quality_Score  42.444003
# 7            Loss_During_Brewing   7.562327
# 8       Loss_During_Fermentation   7.592785
# 9   Loss_During_Bottling_Kegging   7.654877
# 10                        Grains  16.559204
# 11                          Hops  12.429982
# 12                Beer_Style_IPA   1.983230
# 13              Beer_Style_Lager   1.979467
# 14            Beer_Style_Pilsner   1.973123
# 15             Beer_Style_Porter   1.963889
# 16               Beer_Style_Sour   1.989466
# 17              Beer_Style_Stout   1.985234
# 18         Beer_Style_Wheat Beer   1.966990
# 19                      SKU_Cans   1.968895
# ...

# %%
features = X.drop(["Brew_Date", "Gravity", "pH_Level", "Brewhouse_Efficiency", "Alcohol_Content"], axis=1)
calculate_vif(features)
# Out:
#                         features  VIF_Value
# 0                       Batch_ID   3.920376
# 1              Fermentation_Time  23.442907
# 2                    Temperature  38.262220
# 3                     Bitterness  11.916956
# 4                          Color   8.446244
# 5                  Quality_Score  37.907472
# 6            Loss_During_Brewing   7.459327
# 7       Loss_During_Fermentation   7.493168
# 8   Loss_During_Bottling_Kegging   7.539859
# 9                         Grains  16.011090
# 10                          Hops  12.145339
# 11                Beer_Style_IPA   1.968671
# 12              Beer_Style_Lager   1.963303
# 13            Beer_Style_Pilsner   1.957137
# 14             Beer_Style_Porter   1.949301
# 15               Beer_Style_Sour   1.975645
# 16              Beer_Style_Stout   1.970077
# 17         Beer_Style_Wheat Beer   1.951269
# 18                      SKU_Cans   1.962072
# 19                      SKU_Kegs   1.962760
# ...

# %%
features = X.drop(["Brew_Date", "Gravity", "pH_Level", "Brewhouse_Efficiency", "Alcohol_Content", "Temperature"], axis=1)
calculate_vif(features)
# Out:
#                         features  VIF_Value
# 0                       Batch_ID   3.902449
# 1              Fermentation_Time  22.424820
# 2                     Bitterness  11.715175
# 3                          Color   8.359105
# 4                  Quality_Score  34.664136
# 5            Loss_During_Brewing   7.390644
# 6       Loss_During_Fermentation   7.420235
# 7   Loss_During_Bottling_Kegging   7.472164
# 8                         Grains  15.633977
# 9                           Hops  11.941538
# 10                Beer_Style_IPA   1.958156
# 11              Beer_Style_Lager   1.951171
# 12            Beer_Style_Pilsner   1.944278
# 13             Beer_Style_Porter   1.936818
# 14               Beer_Style_Sour   1.963876
# 15              Beer_Style_Stout   1.957937
# 16         Beer_Style_Wheat Beer   1.939304
# 17                      SKU_Cans   1.957209
# 18                      SKU_Kegs   1.957600
# 19                     SKU_Pints   1.957721
# ...

# %%
features = X.drop(["Brew_Date", "Gravity", "pH_Level", "Brewhouse_Efficiency", "Alcohol_Content", "Temperature", "Fermentation_Time"], axis=1)
calculate_vif(features)
# Out:
#                         features  VIF_Value
# 0                       Batch_ID   3.886997
# 1                     Bitterness  11.563331
# 2                          Color   8.282742
# 3                  Quality_Score  31.974688
# 4            Loss_During_Brewing   7.339439
# 5       Loss_During_Fermentation   7.355165
# 6   Loss_During_Bottling_Kegging   7.419478
# 7                         Grains  15.317304
# 8                           Hops  11.764266
# 9                 Beer_Style_IPA   1.950384
# 10              Beer_Style_Lager   1.942731
# 11            Beer_Style_Pilsner   1.936975
# 12             Beer_Style_Porter   1.927539
# 13               Beer_Style_Sour   1.953233
# 14              Beer_Style_Stout   1.948218
# 15         Beer_Style_Wheat Beer   1.930831
# 16                      SKU_Cans   1.953483
# 17                      SKU_Kegs   1.953823
# 18                     SKU_Pints   1.955196
# 19           Location_HSR Layout   1.921654
# ...

# %%
features = X.drop(["Brew_Date", "Gravity", "pH_Level", "Brewhouse_Efficiency", "Alcohol_Content", "Temperature", "Fermentation_Time", "Quality_Score"], axis=1)
calculate_vif(features)
# Out:
#                         features  VIF_Value
# 0                       Batch_ID   3.842168
# 1                     Bitterness  11.039299
# 2                          Color   8.029999
# 3            Loss_During_Brewing   7.120245
# 4       Loss_During_Fermentation   7.144364
# 5   Loss_During_Bottling_Kegging   7.211711
# 6                         Grains  14.236167
# 7                           Hops  11.197853
# 8                 Beer_Style_IPA   1.921411
# 9               Beer_Style_Lager   1.913443
# 10            Beer_Style_Pilsner   1.907454
# 11             Beer_Style_Porter   1.898178
# 12               Beer_Style_Sour   1.922531
# 13              Beer_Style_Stout   1.918124
# 14         Beer_Style_Wheat Beer   1.902291
# 15                      SKU_Cans   1.938059
# 16                      SKU_Kegs   1.938010
# 17                     SKU_Pints   1.939217
# 18           Location_HSR Layout   1.883157
# 19          Location_Indiranagar   1.905717
# ...

# %%
features = X.drop(["Brew_Date", "Gravity", "pH_Level", "Brewhouse_Efficiency", "Alcohol_Content", "Temperature", "Fermentation_Time", "Quality_Score", "Grains"], axis=1)
calculate_vif(features)
# Out:
#                         features  VIF_Value
# 0                       Batch_ID   3.813963
# 1                     Bitterness  10.699222
# 2                          Color   7.871223
# 3            Loss_During_Brewing   6.992369
# 4       Loss_During_Fermentation   7.021129
# 5   Loss_During_Bottling_Kegging   7.075202
# 6                           Hops  10.796294
# 7                 Beer_Style_IPA   1.902812
# 8               Beer_Style_Lager   1.892655
# 9             Beer_Style_Pilsner   1.885572
# 10             Beer_Style_Porter   1.878249
# 11               Beer_Style_Sour   1.904374
# 12              Beer_Style_Stout   1.898589
# 13         Beer_Style_Wheat Beer   1.882845
# 14                      SKU_Cans   1.928977
# 15                      SKU_Kegs   1.930465
# 16                     SKU_Pints   1.930303
# 17           Location_HSR Layout   1.858511
# 18          Location_Indiranagar   1.881832
# 19            Location_Jayanagar   1.877950
# ...

# %%
features = X.drop(["Brew_Date", "Gravity", "pH_Level", "Brewhouse_Efficiency", "Alcohol_Content", "Temperature", "Fermentation_Time", "Quality_Score", "Grains", "Hops"], axis=1)
calculate_vif(features)
# Out:
#                         features  VIF_Value
# 0                       Batch_ID   3.784027
# 1                     Bitterness  10.326883
# 2                          Color   7.696966
# 3            Loss_During_Brewing   6.859591
# 4       Loss_During_Fermentation   6.883064
# 5   Loss_During_Bottling_Kegging   6.948767
# 6                 Beer_Style_IPA   1.884819
# 7               Beer_Style_Lager   1.875359
# 8             Beer_Style_Pilsner   1.864453
# 9              Beer_Style_Porter   1.859314
# 10               Beer_Style_Sour   1.885689
# 11              Beer_Style_Stout   1.877756
# 12         Beer_Style_Wheat Beer   1.865445
# 13                      SKU_Cans   1.918207
# 14                      SKU_Kegs   1.920271
# 15                     SKU_Pints   1.919241
# 16           Location_HSR Layout   1.833698
# 17          Location_Indiranagar   1.854404
# 18            Location_Jayanagar   1.852669
# 19          Location_Koramangala   1.849664
# ...

# %%
features = X.drop(["Brew_Date", "Gravity", "pH_Level", "Brewhouse_Efficiency", "Alcohol_Content", "Temperature", "Fermentation_Time", "Quality_Score", "Grains", "Hops", "Bitterness"], axis=1)
calculate_vif(features)
# Out:
#                         features  VIF_Value
# 0                       Batch_ID   3.737840
# 1                          Color   7.439082
# 2            Loss_During_Brewing   6.667191
# 3       Loss_During_Fermentation   6.714085
# 4   Loss_During_Bottling_Kegging   6.749182
# 5                 Beer_Style_IPA   1.852475
# 6               Beer_Style_Lager   1.845072
# 7             Beer_Style_Pilsner   1.833293
# 8              Beer_Style_Porter   1.827585
# 9                Beer_Style_Sour   1.854481
# 10              Beer_Style_Stout   1.847017
# 11         Beer_Style_Wheat Beer   1.831912
# 12                      SKU_Cans   1.903689
# 13                      SKU_Kegs   1.906688
# 14                     SKU_Pints   1.904283
# 15           Location_HSR Layout   1.798646
# 16          Location_Indiranagar   1.820129
# 17            Location_Jayanagar   1.817094
# 18          Location_Koramangala   1.815395
# 19          Location_Malleswaram   1.818435
# ...

# %%
features = X.drop(["Brew_Date", "Gravity", "pH_Level", "Brewhouse_Efficiency", "Alcohol_Content", "Temperature", "Fermentation_Time", "Quality_Score", "Grains", "Hops", "Bitterness", "Color"], axis=1)
calculate_vif(features)
# Out:
#                         features  VIF_Value
# 0                       Batch_ID   3.699609
# 1            Loss_During_Brewing   6.475857
# 2       Loss_During_Fermentation   6.531205
# 3   Loss_During_Bottling_Kegging   6.579325
# 4                 Beer_Style_IPA   1.823097
# 5               Beer_Style_Lager   1.813655
# 6             Beer_Style_Pilsner   1.805475
# 7              Beer_Style_Porter   1.798162
# 8                Beer_Style_Sour   1.824724
# 9               Beer_Style_Stout   1.817151
# 10         Beer_Style_Wheat Beer   1.800243
# 11                      SKU_Cans   1.889986
# 12                      SKU_Kegs   1.892977
# 13                     SKU_Pints   1.891618
# 14           Location_HSR Layout   1.758585
# 15          Location_Indiranagar   1.785046
# 16            Location_Jayanagar   1.775441
# 17          Location_Koramangala   1.779912
# 18          Location_Malleswaram   1.785831
# 19         Location_Marathahalli   1.766668
# ...

# %%
features = X.drop(["Brew_Date", "Gravity", "pH_Level", "Brewhouse_Efficiency", "Alcohol_Content", "Temperature", "Fermentation_Time", "Quality_Score", "Grains", "Hops", "Bitterness", "Color", "Loss_During_Bottling_Kegging"], axis=1)
calculate_vif(features)
# Out:
#                     features  VIF_Value
# 0                   Batch_ID   3.646196
# 1        Loss_During_Brewing   6.268039
# 2   Loss_During_Fermentation   6.280458
# 3             Beer_Style_IPA   1.784444
# 4           Beer_Style_Lager   1.774136
# 5         Beer_Style_Pilsner   1.768188
# 6          Beer_Style_Porter   1.760193
# 7            Beer_Style_Sour   1.786345
# 8           Beer_Style_Stout   1.780072
# 9      Beer_Style_Wheat Beer   1.764814
# 10                  SKU_Cans   1.874593
# 11                  SKU_Kegs   1.877054
# 12                 SKU_Pints   1.875891
# 13       Location_HSR Layout   1.719440
# 14      Location_Indiranagar   1.744728
# 15        Location_Jayanagar   1.734851
# 16      Location_Koramangala   1.738430
# 17      Location_Malleswaram   1.745431
# 18     Location_Marathahalli   1.726353
# 19      Location_Rajajinagar   1.733947
# 20       Location_Whitefield   1.734553
# 21        Location_Yelahanka   1.715109

# %%
features = X.drop(["Brew_Date", "Gravity", "pH_Level", "Brewhouse_Efficiency", "Alcohol_Content", "Temperature", "Fermentation_Time", "Quality_Score", "Grains", "Hops", "Bitterness", "Color", "Loss_During_Bottling_Kegging", "Loss_During_Brewing"], axis=1)
calculate_vif(features)
# Out:
#                     features  VIF_Value
# 0                   Batch_ID   3.572536
# 1   Loss_During_Fermentation   5.945988
# 2             Beer_Style_IPA   1.735482
# 3           Beer_Style_Lager   1.726909
# 4         Beer_Style_Pilsner   1.722718
# 5          Beer_Style_Porter   1.713309
# 6            Beer_Style_Sour   1.742403
# 7           Beer_Style_Stout   1.731772
# 8      Beer_Style_Wheat Beer   1.715880
# 9                   SKU_Cans   1.852500
# 10                  SKU_Kegs   1.853387
# 11                 SKU_Pints   1.851808
# 12       Location_HSR Layout   1.655601
# 13      Location_Indiranagar   1.679826
# 14        Location_Jayanagar   1.671356
# 15      Location_Koramangala   1.672918
# 16      Location_Malleswaram   1.681782
# 17     Location_Marathahalli   1.664197
# 18      Location_Rajajinagar   1.668495
# 19       Location_Whitefield   1.672286
# 20        Location_Yelahanka   1.655905

# %%
features = X.drop(["Brew_Date", "Gravity", "pH_Level", "Brewhouse_Efficiency", "Alcohol_Content", "Temperature", "Fermentation_Time", "Quality_Score", "Grains", "Hops", "Bitterness", "Color", "Loss_During_Bottling_Kegging", "Loss_During_Brewing", "Loss_During_Fermentation"], axis=1)
calculate_vif(features)
# Out:
#                  features  VIF_Value
# 0                Batch_ID   3.455668
# 1          Beer_Style_IPA   1.661633
# 2        Beer_Style_Lager   1.649354
# 3      Beer_Style_Pilsner   1.649262
# 4       Beer_Style_Porter   1.636915
# 5         Beer_Style_Sour   1.663477
# 6        Beer_Style_Stout   1.652644
# 7   Beer_Style_Wheat Beer   1.642359
# 8                SKU_Cans   1.812582
# 9                SKU_Kegs   1.816456
# 10              SKU_Pints   1.812512
# 11    Location_HSR Layout   1.560584
# 12   Location_Indiranagar   1.579583
# 13     Location_Jayanagar   1.564573
# 14   Location_Koramangala   1.572438
# 15   Location_Malleswaram   1.582440
# 16  Location_Marathahalli   1.562619
# 17   Location_Rajajinagar   1.567434
# 18    Location_Whitefield   1.572401
# 19     Location_Yelahanka   1.556512

# %%
# We ended up dropping most of the variables, leaving us with beer style, SKU (packaging), and location (other variables were causing
# multicollinearity). Database creator mentioned that there is only a small set of variables that would affect price per liter. I am generally
# not surprised to see the multicollenearity because most of the parameters we dropped would define the beer style.

# %%
# We additionally need to drop Batch_ID from our independent variables because it is a randomly assigned ID
X = X.drop(["Brew_Date", "Gravity", "pH_Level", "Brewhouse_Efficiency", "Alcohol_Content", "Temperature", "Fermentation_Time", "Quality_Score", "Grains", "Hops", "Bitterness", "Color", "Loss_During_Bottling_Kegging", "Loss_During_Brewing", "Loss_During_Fermentation", "Batch_ID"], axis=1)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=17)

# %%
from sklearn.linear_model import LinearRegression 

regression_model = LinearRegression()
regression_model.fit(X_train, y_train)

print(regression_model.score(X_train, y_train))
print(regression_model.score(X_test, y_test))
# Out:
# 0.000504417096649723
# -0.00048346285376132947

# %%
X_withconstant = sm.add_constant(X)

myregression = sm.OLS(y, X_withconstant)
myregression_results = myregression.fit()
myregression_results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:      Revenue_Per_Liter   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                  0.000
# Method:                 Least Squares   F-statistic:                     1.169
# Date:                Tue, 02 Jan 2024   Prob (F-statistic):              0.274
# Time:                        17:34:38   Log-Likelihood:            -1.5363e+05
# No. Observations:               50000   AIC:                         3.073e+05
# Df Residuals:                   49980   BIC:                         3.075e+05
# Df Model:                          19
# Covariance Type:            nonrobust
# ...
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# ...

# %%
# Looks like there is a very low predictive power in this model. Probably explained by the fact that correlations between independent variables
# and the dependent variable are very low.

# %% [markdown]
# <font color='red'>NTD - check normality of distribution of the residuals and homoscedasticity </font>

# %% [markdown]
# ### Decision Tree

# %%
# Let's reset X and y to include all variables within the set of independent variables
X = brews_df.drop(["Revenue_Per_Liter", "Brew_Date", "Batch_ID"], axis=1)
y = brews_df["Revenue_Per_Liter"]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=17)

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
X
# Out:
#          Fermentation_Time  Temperature  pH_Level   Gravity  Alcohol_Content  \
# 2962955                 19    17.830804  5.267129  1.035899         5.123284
# 7621982                 19    21.316022  4.870337  1.072140         4.653873
# 4254350                 13    16.605831  5.143604  1.056021         5.690139
# 7873153                 14    17.062998  5.211564  1.061697         4.888406
# 7869034                 12    21.546932  5.322301  1.041031         5.813500
# ...                    ...          ...       ...       ...              ...
# 6528231                 14    18.169694  4.979299  1.070393         5.542137
# 6714322                 13    19.278770  5.247504  1.053412         5.077654
# 5823790                 11    16.482225  5.073970  1.048758         4.553186
# 7127                    16    24.331978  4.741981  1.063435         4.500345
# 7445576                 12    16.706613  4.929742  1.041740         5.942539
#
# ...

# %%
scores = pd.DataFrame()
scores = {
    'Depth': [],
    'Train Score': [],
    'Test Score': []
}

depth_range = 20

# loop through the max depth values
for max_depth in range(1, depth_range):
    dt_model = DecisionTreeClassifier(max_depth=max_depth)
    dt_model.fit(X_train, y_train)
    
    # scoring
    train_score = dt_model.score(X_train, y_train)
    test_score = dt_model.score(X_test, y_test)
    
    # append results
    # scores = scores.append({'Depth': max_depth, 'Train Score': train_score, 'Test Score': train_score}, ignore_index=True)
    scores['Depth'].append(max_depth)
    scores['Train Score'].append(train_score)
    scores['Test Score'].append(test_score)

scores_df = pd.DataFrame(scores)

# best parameter
best_score = scores_df['Test Score'].max()
print("Best test scores given by:")
print(scores_df[scores_df['Test Score'] == best_score], "\n\n")

# comparison plot
plt.figure(figsize=(10,5))
plt.plot('Depth', 'Train Score', data=scores_df)
plt.plot('Depth', 'Test Score', data=scores_df)
plt.title('Accuracies as Depth Changes')
plt.xlabel('Depth')
plt.xticks(range(1,depth_range, 2))
plt.ylabel('Accuracy Score')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[78], line 13
#      11 for max_depth in range(1, depth_range):
#      12     dt_model = DecisionTreeClassifier(max_depth=max_depth)
# ---> 13     dt_model.fit(X_train, y_train)
#      15     # scoring
#      16     train_score = dt_model.score(X_train, y_train)
#
# File ~\anaconda3\Lib\site-packages\sklearn\base.py:1151, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1144     estimator._validate_params()
#    1146 with config_context(
#    1147     skip_parameter_validation=(
#    1148         prefer_skip_nested_validation or global_skip_validation
#    1149     )
#    1150 ):
# -> 1151     return fit_method(estimator, *args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\sklearn\tree\_classes.py:959, in DecisionTreeClassifier.fit(self, X, y, sample_weight, check_input)
# ...
